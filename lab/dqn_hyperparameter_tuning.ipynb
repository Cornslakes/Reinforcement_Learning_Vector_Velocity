# %% [markdown]
#  # Code was run on https://www.kaggle.com/

# %% [markdown]
# # Hyperparameter tuning for DQN using Optuna

# %%
# !pip install vector-velocity-gym
# Out:
# Collecting vector-velocity-gym
#   Downloading vector_velocity_gym-0.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gymnasium in /opt/conda/lib/python3.10/site-packages (from vector-velocity-gym) (0.29.0)
# Collecting pygame (from vector-velocity-gym)
#   Downloading pygame-2.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from vector-velocity-gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium->vector-velocity-gym) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium->vector-velocity-gym) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium->vector-velocity-gym) (0.0.4)
# Downloading vector_velocity_gym-0.1.0-py3-none-any.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 69.4 MB/s eta 0:00:00
# Downloading pygame-2.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 85.1 MB/s eta 0:00:00
# Installing collected packages: pygame, vector-velocity-gym
# Successfully installed pygame-2.6.0 vector-velocity-gym-0.1.0

# %%
import os
import torch
import optuna
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from gym_vectorvelocity import VectorVelocityEnv
from stable_baselines3.common.env_checker import check_env
from gymnasium import make
# Out:
# 2024-07-25 15:15:30.935836: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-25 15:15:30.935989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-25 15:15:31.062558: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Setup

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
n_cores = os.cpu_count()
print(f"Using {n_cores} cores for training.")
# Out:
# Using 4 cores for training.

# %% [markdown]
# ### Initialize environment

# %%
# env modifications if needed
GAMEOVER_PENALTY = 75
MISSED_COIN_PENALTY = 3

DODGED_OBSTACLE_REWARD = 1
COLLECTED_COIN_REWARD = 12

def create_env():
    env = VectorVelocityEnv()
    env.coin_missed_penalty = MISSED_COIN_PENALTY
    env.game_over_penalty = GAMEOVER_PENALTY
    env.dodged_obstacle_reward = DODGED_OBSTACLE_REWARD
    env.coin_reward = COLLECTED_COIN_REWARD
    return env

env = create_env()
check_env(env)

# %%
env = make('VectorVelocity-v0')
env = DummyVecEnv([lambda: env])

# %% [markdown]
# ### Define trial

# %%
def objective(trial):

    # Suggest hyperparameters
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True)
    gamma = trial.suggest_float('gamma', 0.9, 0.9999)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256])
    buffer_size = trial.suggest_int('buffer_size', 10000, 100000)
    exploration_fraction = trial.suggest_float('exploration_fraction', 0.1, 0.5)
    exploration_final_eps = trial.suggest_float('exploration_final_eps', 0.01, 0.1)
    
    # Create the model
    model = DQN(
        "MultiInputPolicy",
        env,
        learning_rate=learning_rate,
        gamma=gamma,
        batch_size=batch_size,
        buffer_size=buffer_size,
        exploration_fraction=exploration_fraction,
        exploration_final_eps=exploration_final_eps,
        verbose=1
    )
    
    # Train the model
    model.learn(total_timesteps=100000)
    
    # Evaluate the model
    mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=20, deterministic=True)
    
    return mean_reward

# %% [markdown]
# ### Start optimization

# %%
#Create the Optuna study with a storage URL
storage_url = "sqlite:///hyperparameter_tuning_data.db"
study = optuna.create_study(storage=storage_url, direction='maximize', study_name='dqn_hyperparameter_tuning')

# Run the optimization with multiprocessing
study.optimize(objective, n_trials=50, n_jobs=n_cores)

# Print the best hyperparameters
print("Best hyperparameters: ", study.best_params)
# Out:
# [I 2024-07-25 15:15:43,856] A new study created in RDB with name: dqn_hyperparameter_tuning
# Using cuda device
# Using cuda device
# Using cuda device
# Using cuda device
# /opt/conda/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 4961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 7384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.672    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 10034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 10991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 16672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 16851    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 18686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.127    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 19060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.139    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 19587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 26733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 26916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 483      |
# |    total_timesteps  | 29904    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 498      |
# |    total_timesteps  | 30789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 544      |
# |    total_timesteps  | 33641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 35415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 37214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 618      |
# |    total_timesteps  | 38199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 61       |
# |    time_elapsed     | 648      |
# |    total_timesteps  | 40070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 704      |
# |    total_timesteps  | 43549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 46075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 46251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 61       |
# |    time_elapsed     | 769      |
# |    total_timesteps  | 47562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 61       |
# |    time_elapsed     | 827      |
# |    total_timesteps  | 50545    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.00198  |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 59       |
# |    time_elapsed     | 881      |
# |    total_timesteps  | 52118    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 58       |
# |    time_elapsed     | 898      |
# |    total_timesteps  | 52634    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.000234 |
# |    n_updates        | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 58       |
# |    time_elapsed     | 905      |
# |    total_timesteps  | 52936    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000454 |
# |    n_updates        | 733      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 56       |
# |    time_elapsed     | 983      |
# |    total_timesteps  | 55300    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.000598 |
# |    n_updates        | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 55       |
# |    time_elapsed     | 1011     |
# |    total_timesteps  | 55988    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.00118  |
# |    n_updates        | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 55       |
# |    time_elapsed     | 1018     |
# |    total_timesteps  | 56186    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 9.79e-05 |
# |    n_updates        | 1546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 53       |
# |    time_elapsed     | 1081     |
# |    total_timesteps  | 58292    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.000193 |
# |    n_updates        | 2072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 53       |
# |    time_elapsed     | 1101     |
# |    total_timesteps  | 58698    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 5.02e-05 |
# |    n_updates        | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 53       |
# |    time_elapsed     | 1108     |
# |    total_timesteps  | 59187    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000153 |
# |    n_updates        | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 52       |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 60184    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.00102  |
# |    n_updates        | 2545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 51       |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 61799    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000205 |
# |    n_updates        | 2949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 51       |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 61866    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 2966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 50       |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 62346    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 9.87e-05 |
# |    n_updates        | 3086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 50       |
# |    time_elapsed     | 1259     |
# |    total_timesteps  | 63414    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000888 |
# |    n_updates        | 3353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 50       |
# |    time_elapsed     | 1284     |
# |    total_timesteps  | 64519    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000271 |
# |    n_updates        | 3629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 49       |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 65230    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.000181 |
# |    n_updates        | 3807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 48       |
# |    time_elapsed     | 1402     |
# |    total_timesteps  | 67560    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.000128 |
# |    n_updates        | 4389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 48       |
# |    time_elapsed     | 1411     |
# |    total_timesteps  | 67849    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000291 |
# |    n_updates        | 4462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 48       |
# |    time_elapsed     | 1411     |
# |    total_timesteps  | 68207    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.000216 |
# |    n_updates        | 4551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 47       |
# |    time_elapsed     | 1481     |
# |    total_timesteps  | 70393    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.583    |
# |    n_updates        | 5098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 47       |
# |    time_elapsed     | 1488     |
# |    total_timesteps  | 70040    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.00141  |
# |    n_updates        | 5009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 46       |
# |    time_elapsed     | 1524     |
# |    total_timesteps  | 71537    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.583    |
# |    n_updates        | 5384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 46       |
# |    time_elapsed     | 1530     |
# |    total_timesteps  | 71891    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 8.42e-05 |
# |    n_updates        | 5472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 46       |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 72340    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000179 |
# |    n_updates        | 5584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 45       |
# |    time_elapsed     | 1622     |
# |    total_timesteps  | 74632    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000243 |
# |    n_updates        | 6157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 45       |
# |    time_elapsed     | 1671     |
# |    total_timesteps  | 75383    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 8.12e-05 |
# |    n_updates        | 6345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 44       |
# |    time_elapsed     | 1779     |
# |    total_timesteps  | 79136    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 8.9e-05  |
# |    n_updates        | 7283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 44       |
# |    time_elapsed     | 1794     |
# |    total_timesteps  | 79020    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 9.45e-05 |
# |    n_updates        | 7254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 43       |
# |    time_elapsed     | 1817     |
# |    total_timesteps  | 79712    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000447 |
# |    n_updates        | 7427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 43       |
# |    time_elapsed     | 1899     |
# |    total_timesteps  | 83016    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.583    |
# |    n_updates        | 8253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 43       |
# |    time_elapsed     | 1935     |
# |    total_timesteps  | 83253    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000127 |
# |    n_updates        | 8313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 43       |
# |    time_elapsed     | 1961     |
# |    total_timesteps  | 84625    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 8656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 42       |
# |    time_elapsed     | 2055     |
# |    total_timesteps  | 87679    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000183 |
# |    n_updates        | 9419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 42       |
# |    time_elapsed     | 2074     |
# |    total_timesteps  | 87251    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.000134 |
# |    n_updates        | 9312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 42       |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 89172    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.0003   |
# |    n_updates        | 9792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 41       |
# |    time_elapsed     | 2121     |
# |    total_timesteps  | 88723    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000352 |
# |    n_updates        | 9680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 42       |
# |    time_elapsed     | 2127     |
# |    total_timesteps  | 89809    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.000444 |
# |    n_updates        | 9952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 41       |
# |    time_elapsed     | 2204     |
# |    total_timesteps  | 91030    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.000144 |
# |    n_updates        | 10257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 41       |
# |    time_elapsed     | 2208     |
# |    total_timesteps  | 91970    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.000646 |
# |    n_updates        | 10492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0269   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 40       |
# |    time_elapsed     | 2306     |
# |    total_timesteps  | 94051    |
# | train/              |          |
# |    learning_rate    | 2.28e-05 |
# |    loss             | 0.000855 |
# |    n_updates        | 11012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0331   |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 40       |
# |    time_elapsed     | 2367     |
# |    total_timesteps  | 96876    |
# | train/              |          |
# |    learning_rate    | 0.00054  |
# |    loss             | 0.00712  |
# |    n_updates        | 11718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0116   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 40       |
# |    time_elapsed     | 2451     |
# |    total_timesteps  | 99161    |
# | train/              |          |
# |    learning_rate    | 4.23e-05 |
# |    loss             | 0.293    |
# |    n_updates        | 12290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0265   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 39       |
# |    time_elapsed     | 2466     |
# |    total_timesteps  | 98598    |
# | train/              |          |
# |    learning_rate    | 0.000365 |
# |    loss             | 0.292    |
# |    n_updates        | 12149    |
# ----------------------------------
# /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2024-07-25 16:15:22,173] Trial 1 finished with value: 226.9585200035903 and parameters: {'learning_rate': 0.00036489688346954364, 'gamma': 0.9054250802048465, 'batch_size': 256, 'buffer_size': 86485, 'exploration_fraction': 0.29763301813026377, 'exploration_final_eps': 0.026544085130239398}. Best is trial 1 with value: 226.9585200035903.
# Using cuda device
# [I 2024-07-25 16:15:28,162] Trial 2 finished with value: 229.9487512079113 and parameters: {'learning_rate': 0.0005402517507189158, 'gamma': 0.9970368887001033, 'batch_size': 128, 'buffer_size': 94288, 'exploration_fraction': 0.21105863655073628, 'exploration_final_eps': 0.033120411044446955}. Best is trial 2 with value: 229.9487512079113.
# Using cuda device
# [I 2024-07-25 16:15:48,033] Trial 3 finished with value: 234.11155908532865 and parameters: {'learning_rate': 4.225700481609194e-05, 'gamma': 0.9187010903308369, 'batch_size': 256, 'buffer_size': 27156, 'exploration_fraction': 0.23879871227142144, 'exploration_final_eps': 0.011576892784178689}. Best is trial 3 with value: 234.11155908532865.
# Using cuda device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 4393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 6395     |
# ----------------------------------
# [I 2024-07-25 16:17:25,488] Trial 0 finished with value: 242.18506515581117 and parameters: {'learning_rate': 2.280273827386646e-05, 'gamma': 0.9592251881094116, 'batch_size': 256, 'buffer_size': 14782, 'exploration_fraction': 0.22146868394466548, 'exploration_final_eps': 0.02694855175262556}. Best is trial 0 with value: 242.18506515581117.
# Using cuda device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.775    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 6346     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 10540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 61       |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 7099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 15963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.251    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 18957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 21131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 21926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 24078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 61       |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 17403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.37     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 29186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 490      |
# |    total_timesteps  | 30129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.561    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 61       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 23922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 533      |
# |    total_timesteps  | 32763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.169    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 626      |
# |    total_timesteps  | 38477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 654      |
# |    total_timesteps  | 40216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.086    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 61       |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 42323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 61       |
# |    time_elapsed     | 623      |
# |    total_timesteps  | 38318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 61       |
# |    time_elapsed     | 781      |
# |    total_timesteps  | 48005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 664      |
# |    total_timesteps  | 40793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 61       |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 49017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 60       |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 51195    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.00191  |
# |    n_updates        | 298      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 61       |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 46275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 59       |
# |    time_elapsed     | 897      |
# |    total_timesteps  | 53417    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.00119  |
# |    n_updates        | 854      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 59       |
# |    time_elapsed     | 926      |
# |    total_timesteps  | 54750    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.0019   |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 61       |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 49588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 58       |
# |    time_elapsed     | 954      |
# |    total_timesteps  | 55820    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 5.41e-05 |
# |    n_updates        | 1454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 60       |
# |    time_elapsed     | 837      |
# |    total_timesteps  | 50687    |
# | train/              |          |
# |    learning_rate    | 1.83e-05 |
# |    loss             | 0.00271  |
# |    n_updates        | 171      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 57       |
# |    time_elapsed     | 981      |
# |    total_timesteps  | 56619    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.00148  |
# |    n_updates        | 1654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 57       |
# |    time_elapsed     | 987      |
# |    total_timesteps  | 56434    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.00116  |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 55       |
# |    time_elapsed     | 1059     |
# |    total_timesteps  | 59208    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 0.00038  |
# |    n_updates        | 2301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 53       |
# |    time_elapsed     | 1138     |
# |    total_timesteps  | 61290    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.000915 |
# |    n_updates        | 2822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 53       |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 63106    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 0.000418 |
# |    n_updates        | 3276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 54       |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 58612    |
# | train/              |          |
# |    learning_rate    | 1.83e-05 |
# |    loss             | 0.00126  |
# |    n_updates        | 2152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 52       |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 63533    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.000349 |
# |    n_updates        | 3383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 52       |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 64744    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.00134  |
# |    n_updates        | 3685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 52       |
# |    time_elapsed     | 1268     |
# |    total_timesteps  | 66131    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.00115  |
# |    n_updates        | 4032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 53       |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 61101    |
# | train/              |          |
# |    learning_rate    | 1.83e-05 |
# |    loss             | 0.00171  |
# |    n_updates        | 2775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 51       |
# |    time_elapsed     | 1297     |
# |    total_timesteps  | 66657    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.000298 |
# |    n_updates        | 4164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 51       |
# |    time_elapsed     | 1338     |
# |    total_timesteps  | 68526    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 0.000416 |
# |    n_updates        | 4631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 50       |
# |    time_elapsed     | 1431     |
# |    total_timesteps  | 71564    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.00184  |
# |    n_updates        | 5390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0867   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 49       |
# |    time_elapsed     | 1453     |
# |    total_timesteps  | 71831    |
# | train/              |          |
# |    learning_rate    | 2.51e-05 |
# |    loss             | 0.000185 |
# |    n_updates        | 5457     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 50       |
# |    time_elapsed     | 1355     |
# |    total_timesteps  | 67992    |
# | train/              |          |
# |    learning_rate    | 1.83e-05 |
# |    loss             | 0.00048  |
# |    n_updates        | 4497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 49       |
# |    time_elapsed     | 1488     |
# |    total_timesteps  | 73548    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 0.000106 |
# |    n_updates        | 5886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0662   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 48       |
# |    time_elapsed     | 1581     |
# |    total_timesteps  | 76584    |
# | train/              |          |
# |    learning_rate    | 1.63e-05 |
# |    loss             | 0.00119  |
# |    n_updates        | 6645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 48       |
# |    time_elapsed     | 1587     |
# |    total_timesteps  | 76844    |
# | train/              |          |
# |    learning_rate    | 0.000208 |
# |    loss             | 0.000259 |
# |    n_updates        | 6710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 48       |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 73990    |
# | train/              |          |
# |    learning_rate    | 1.83e-05 |
# |    loss             | 0.000781 |
# |    n_updates        | 5997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.028    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 47       |
# |    time_elapsed     | 1684     |
# |    total_timesteps  | 80059    |
# | train/              |          |
# ...
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 51       |
# |    time_elapsed     | 1438     |
# |    total_timesteps  | 74002    |
# | train/              |          |
# |    learning_rate    | 8.11e-05 |
# |    loss             | 1.86e-05 |
# |    n_updates        | 6000     |
# ----------------------------------
# [I 2024-07-26 00:47:29,371] Trial 46 finished with value: 3.3647842562246297 and parameters: {'learning_rate': 0.00022351588731394254, 'gamma': 0.988938539736984, 'batch_size': 64, 'buffer_size': 30278, 'exploration_fraction': 0.378493130022841, 'exploration_final_eps': 0.03509405675536626}. Best is trial 0 with value: 242.18506515581117.
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 50       |
# |    time_elapsed     | 1464     |
# |    total_timesteps  | 74386    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 0.000114 |
# |    n_updates        | 6096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 60       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 21982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 60       |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 24932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0373   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 50       |
# |    time_elapsed     | 1584     |
# |    total_timesteps  | 80687    |
# | train/              |          |
# |    learning_rate    | 8.11e-05 |
# |    loss             | 0.000161 |
# |    n_updates        | 7671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 60       |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 29038    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 50       |
# |    time_elapsed     | 1608     |
# |    total_timesteps  | 81352    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 0.000168 |
# |    n_updates        | 7837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 60       |
# |    time_elapsed     | 593      |
# |    total_timesteps  | 35835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0373   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 50       |
# |    time_elapsed     | 1755     |
# |    total_timesteps  | 89019    |
# | train/              |          |
# |    learning_rate    | 8.11e-05 |
# |    loss             | 7.85e-05 |
# |    n_updates        | 9754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 50       |
# |    time_elapsed     | 1747     |
# |    total_timesteps  | 88090    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 0.000136 |
# |    n_updates        | 9522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0373   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 50       |
# |    time_elapsed     | 1830     |
# |    total_timesteps  | 92657    |
# | train/              |          |
# |    learning_rate    | 8.11e-05 |
# |    loss             | 0.000773 |
# |    n_updates        | 10664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 60       |
# |    time_elapsed     | 680      |
# |    total_timesteps  | 41131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 50       |
# |    time_elapsed     | 1834     |
# |    total_timesteps  | 92295    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 0.000397 |
# |    n_updates        | 10573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 60       |
# |    time_elapsed     | 729      |
# |    total_timesteps  | 44140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0373   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 50       |
# |    time_elapsed     | 1913     |
# |    total_timesteps  | 96681    |
# | train/              |          |
# |    learning_rate    | 8.11e-05 |
# |    loss             | 6.32e-05 |
# |    n_updates        | 11670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 50       |
# |    time_elapsed     | 1867     |
# |    total_timesteps  | 93897    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 5.16e-05 |
# |    n_updates        | 10974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 60       |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 46149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 59       |
# |    time_elapsed     | 873      |
# |    total_timesteps  | 52217    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000853 |
# |    n_updates        | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0352   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 50       |
# |    time_elapsed     | 1986     |
# |    total_timesteps  | 99641    |
# | train/              |          |
# |    learning_rate    | 0.000214 |
# |    loss             | 0.292    |
# |    n_updates        | 12410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 58       |
# |    time_elapsed     | 1007     |
# |    total_timesteps  | 58609    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 2152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 57       |
# |    time_elapsed     | 1111     |
# |    total_timesteps  | 63592    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.00014  |
# |    n_updates        | 3397     |
# ----------------------------------
# [I 2024-07-26 01:01:09,112] Trial 47 finished with value: -15.348235164686741 and parameters: {'learning_rate': 8.107666053852307e-05, 'gamma': 0.9903127309724797, 'batch_size': 64, 'buffer_size': 36858, 'exploration_fraction': 0.2018312867544572, 'exploration_final_eps': 0.03732505423551513}. Best is trial 0 with value: 242.18506515581117.
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 55       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 73365    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.00018  |
# |    n_updates        | 5841     |
# ----------------------------------
# [I 2024-07-26 01:04:09,548] Trial 48 finished with value: 17.62813511302362 and parameters: {'learning_rate': 0.0002141343455180411, 'gamma': 0.9895873900542063, 'batch_size': 256, 'buffer_size': 37735, 'exploration_fraction': 0.34182136669889296, 'exploration_final_eps': 0.03524029754122275}. Best is trial 0 with value: 242.18506515581117.
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 55       |
# |    time_elapsed     | 1365     |
# |    total_timesteps  | 76152    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000127 |
# |    n_updates        | 6537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 55       |
# |    time_elapsed     | 1400     |
# |    total_timesteps  | 78229    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 7057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 55       |
# |    time_elapsed     | 1427     |
# |    total_timesteps  | 79846    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 7.63e-05 |
# |    n_updates        | 7461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 56       |
# |    time_elapsed     | 1453     |
# |    total_timesteps  | 81416    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000389 |
# |    n_updates        | 7853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 56       |
# |    time_elapsed     | 1482     |
# |    total_timesteps  | 83201    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 8.76e-05 |
# |    n_updates        | 8300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 56       |
# |    time_elapsed     | 1541     |
# |    total_timesteps  | 86729    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.293    |
# |    n_updates        | 9182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 56       |
# |    time_elapsed     | 1578     |
# |    total_timesteps  | 88941    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.00117  |
# |    n_updates        | 9735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 56       |
# |    time_elapsed     | 1607     |
# |    total_timesteps  | 90697    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000347 |
# |    n_updates        | 10174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 56       |
# |    time_elapsed     | 1647     |
# |    total_timesteps  | 93091    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000336 |
# |    n_updates        | 10772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 56       |
# |    time_elapsed     | 1675     |
# |    total_timesteps  | 94774    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.292    |
# |    n_updates        | 11193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 56       |
# |    time_elapsed     | 1712     |
# |    total_timesteps  | 97022    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.000297 |
# |    n_updates        | 11755    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0321   |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 56       |
# |    time_elapsed     | 1741     |
# |    total_timesteps  | 98745    |
# | train/              |          |
# |    learning_rate    | 4.85e-05 |
# |    loss             | 0.00049  |
# |    n_updates        | 12186    |
# ----------------------------------
# [I 2024-07-26 01:13:41,942] Trial 49 finished with value: -51.375477691483866 and parameters: {'learning_rate': 4.8537620328904014e-05, 'gamma': 0.990323878603262, 'batch_size': 256, 'buffer_size': 35769, 'exploration_fraction': 0.3961688424759834, 'exploration_final_eps': 0.032097756518451315}. Best is trial 0 with value: 242.18506515581117.
# Best hyperparameters:  {'learning_rate': 2.280273827386646e-05, 'gamma': 0.9592251881094116, 'batch_size': 256, 'buffer_size': 14782, 'exploration_fraction': 0.22146868394466548, 'exploration_final_eps': 0.02694855175262556}

# %% [markdown]
# ### Run dashboard to inspect results

# %%
from optuna_dashboard import run_server
storage_url = "sqlite:///./hyperparameter_tuning_data.db"
# Start the Optuna dashboard
dashboard_proc = run_server(storage_url, host="127.0.0.1", port=8080)
# Out:
# Bottle v0.12.25 server starting up (using WSGIRefServer())...
# Listening on http://127.0.0.1:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [26/Jul/2024 07:53:07] "GET /dashboard/?studies_order_by=desc HTTP/1.1" 200 4145
# 127.0.0.1 - - [26/Jul/2024 07:53:07] "GET /static/bundle.js HTTP/1.1" 200 2986981
# 127.0.0.1 - - [26/Jul/2024 07:53:08] "GET /api/studies HTTP/1.1" 200 153
# d:\Uni\Reinforcement_Learning_Vector_Velocity\reinforcement_learning\lib\site-packages\optuna_dashboard\_importance.py:75: ExperimentalWarning: PedAnovaImportanceEvaluator is experimental (supported from v3.6.0). The interface can change in the future.
#   return get_param_importances(study, target=target, evaluator=PedAnovaImportanceEvaluator())
# d:\Uni\Reinforcement_Learning_Vector_Velocity\reinforcement_learning\lib\site-packages\optuna\importance\_ped_anova\evaluator.py:150: UserWarning: PedAnovaImportanceEvaluator computes the importances of params to achieve low `target` values. If this is not what you want, please modify target, e.g., by multiplying the output by -1.
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2024 07:53:11] "GET /api/studies/1/param_importances HTTP/1.1" 200 625
# 127.0.0.1 - - [26/Jul/2024 07:53:11] "GET /api/studies/1?after=0 HTTP/1.1" 200 104732
# 127.0.0.1 - - [26/Jul/2024 07:53:11] "GET /api/meta HTTP/1.1" 200 64
# 127.0.0.1 - - [26/Jul/2024 07:53:12] "GET /api/studies/1/param_importances HTTP/1.1" 200 625
# 127.0.0.1 - - [26/Jul/2024 07:53:22] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:53:32] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:53:42] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:53:52] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:03] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:13] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:23] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:34] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:44] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:54:55] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:55:06] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:55:17] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:55:28] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:55:39] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:55:50] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:01] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:12] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:23] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:34] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:45] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:56:56] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:57:07] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:57:18] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:57:29] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:57:40] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:57:51] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:02] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:13] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:24] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:35] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:46] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:58:57] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:59:08] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:59:19] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:59:30] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:59:41] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 07:59:52] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:03] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:14] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:24] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:34] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:45] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:00:55] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:05] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:15] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:26] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:36] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:46] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:01:56] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:07] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:17] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:27] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:37] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:47] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:02:58] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:08] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:18] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:28] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:38] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:49] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:03:59] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:04:09] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:04:19] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:04:30] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:04:40] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:04:50] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:00] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:11] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:21] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:31] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:41] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:05:51] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:01] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:12] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:22] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:32] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:42] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:06:53] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:03] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:13] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:23] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:34] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:44] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:07:54] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:04] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:15] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:25] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:35] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:45] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:08:55] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:05] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:16] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:26] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:36] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:46] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:09:57] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:07] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:17] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:27] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:38] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:48] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:10:58] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:08] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:18] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:28] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:39] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:49] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:11:59] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
# 127.0.0.1 - - [26/Jul/2024 08:12:09] "GET /api/studies/1?after=50 HTTP/1.1" 200 4225
